# %% [markdown]
# # Iris Flower Classification
#
# This notebook uses the Iris dataset from scikit-learn to classify flowers into three species: setosa, versicolor, and virginica.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)
acc_tree = accuracy_score(y_test, y_pred_tree)
acc_tree
# Out:
# 1.0

# %%
log_clf = LogisticRegression(max_iter=1000, random_state=42)
log_clf.fit(X_train, y_train)
y_pred_log = log_clf.predict(X_test)
acc_log = accuracy_score(y_test, y_pred_log)
acc_log
# Out:
# 1.0

# %%
print(f"Decision Tree Accuracy: {acc_tree:.3f}")
print(f"Logistic Regression Accuracy: {acc_log:.3f}")
# Out:
# Decision Tree Accuracy: 1.000
# Logistic Regression Accuracy: 1.000

# %%
cm_tree = confusion_matrix(y_test, y_pred_tree)
cm_log = confusion_matrix(y_test, y_pred_log)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

sns.heatmap(cm_tree, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Decision Tree')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(cm_log, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title('Logistic Regression')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Project Summary
#
# In this notebook, I classified the Iris dataset using a decision tree and logistic regression. Both models achieved perfect accuracy on this train-test split, and the confusion matrices show no classification errors. Iris is a realtively easy dataset and thus the split gave both models a perfect score
